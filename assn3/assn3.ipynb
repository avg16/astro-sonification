# %%
# !pip3 install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

# %%
data_np = np.load("./images.npy")
data_np
# Out:
# array([[[[ 68,  19,  23],
#          [ 58,  17,  33],
#          [ 40,  16,  40],
#          ...,
#          [ 51,  46,  43],
#          [ 40,  41,  33],
#          [ 28,  38,  30]],
#
#         [[ 61,  40,  37],
#          [ 52,  43,  44],
#          [ 29,  39,  41],
#          ...,
#          [ 28,  30,  42],
#          [ 28,  32,  35],
#          [ 33,  40,  33]],
#
#         [[ 30,  31,  25],
#          [ 24,  41,  33],
#          [ 15,  45,  33],
#          ...,
#          [ 21,  35,  48],
#          [ 25,  35,  45],
#          [ 37,  41,  40]],
#
#         ...,
#
#         [[ 28,  32,  35],
#          [ 27,  31,  32],
#          [ 42,  44,  43],
#          ...,
#          [ 20,  37,  27],
#          [ 19,  40,  21],
#          [ 27,  50,  24]],
#
#         [[ 22,  36,  37],
#          [ 19,  29,  30],
#          [ 33,  37,  38],
#          ...,
#          [ 17,  35,  35],
#          [ 17,  35,  21],
#          [ 26,  45,  17]],
#
#         [[ 18,  39,  40],
# ...

# %%
data_np.shape
# Out:
# (17736, 256, 256, 3)

# %%
sample = data_np[10000]
image = Image.fromarray(sample)

plt.imshow(image)
